# %% [markdown]
# multiple linear regression is an extension of linear regression as it  takes more than one predictor variable to predict the response variable.
# input-Multiple
# output-single

# %% [markdown]
# if tere are two input x1,x2 and output y. then for multiple lnear regression to work the relationship between x1 and y should be linear and relationship between x2 and y should be linear as well

# %% [markdown]
# y=m1x1+m2x2+m3x3....+c(equation of plane)

# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("../Salary_data.csv")
dataset.head()
#later for improving accuracy we should do scaling
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
dataset.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
sns.pairplot(data= dataset)
plt.show()

# %%
sns.heatmap(data=dataset.corr(),annot=True)
plt.show()
